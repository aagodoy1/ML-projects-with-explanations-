# %% [markdown]
# ### 1) Divide between dataset_training and dataset testing

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

information = pd.read_csv('gcar_data.csv', sep=',')

datatrain, datatest = train_test_split(information, test_size=0.3, random_state=5)

datatrain.to_csv('datatrain.csv',index=False, sep=',')
datatest.to_csv('datatest.csv',index=False, sep=',')

# %% [markdown]
# ### 2) Now we start with the model

# %%
import pandas as pd

df_train = pd.read_csv('datatrain.csv', sep = ',')
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        70000 non-null  int64
#  1   brand                     70000 non-null  object
#  2   model                     70000 non-null  object
#  3   color                     69945 non-null  object
#  4   registration_date         70000 non-null  object
#  5   year                      70000 non-null  object
#  6   price_in_euro             70000 non-null  object
#  7   power_kw                  69944 non-null  object
#  8   power_ps                  69947 non-null  object
#  9   transmission_type         70000 non-null  object
#  10  fuel_type                 70000 non-null  object
#  11  fuel_consumption_l_100km  62118 non-null  object
#  12  fuel_consumption_g_km     70000 non-null  object
#  13  mileage_in_km             69952 non-null  float64
#  14  offer_description         70000 non-null  object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 8.0+ MB

# %%
df_train.head()
# Out:
#       id    brand                         model  color registration_date  \
# 0  81809  hyundai                  Hyundai KONA  white           11/2020
# 1  36126      bmw                       BMW 225   grey           03/2017
# 2  45607  citroen  Citroen Grand C4 SpaceTourer  black           09/2019
# 3  13688     audi                      Audi RS3    red           11/2017
# 4  36065      bmw                        BMW X3  brown           10/2017
#
#    year price_in_euro power_kw power_ps transmission_type fuel_type  \
# 0  2020         29990      150      204         Automatic  Electric
# 1  2017         18990      165      224         Automatic    Hybrid
# 2  2019         16950       96      131         Automatic    Diesel
# 3  2017         39999      294      400         Automatic    Petrol
# 4  2017         33890      195      265         Automatic    Diesel
#
#   fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# 0                      NaN                0 g/km        29000.0
# 1               2 l/100 km               46 g/km        89500.0
# 2               4 l/100 km              106 g/km       139000.0
# 3             8,3 l/100 km              189 g/km        77000.0
# 4             5,7 l/100 km              149 g/km        98996.0
#
#                                 offer_description
# 0          Electric PREMIUM Vollausstattung/LEDER
# 1  225xe Sport Line iPerformance *HUD*LED*Memory*
# 2      1.5 BlueHDi Feel Automatik EU6d Navi Klima
# 3      Sportback 2.5 TFSI quattro*MATRIX*KERAMIK*
# 4     xDrive30d Luxury AHK*Head-Up*Pano*Standhzg*

# %%
#df_train['brand'].value_counts() # Use onehot encode, the brand may affect drastecly the price.
# df_train['model'].value_counts()  #REMOVE MODEL
#df_train['color'].value_counts() # REMOVE
# registration_date # REMOVE
# YEAR -> integer
# price: -> TARGET
# power_ks -> integer
# power_ps -> integer
#df_train['transmission_type'].value_counts() #ONEHOT ENCODER
#df_train['fuel_type'].value_counts() # It has a lot of types, keep only PETROL, DIESEL, HYBRID, ELECTRIC, LPG, DIESEL HYBRID, OTHER. Classify all the rest like "other"
#df_train['fuel_consumption_l_100km'].unique() # we eliminate everything doesn't have l/100 km
#df_train['fuel_consumption_g_km'].unique() # we eliminate everything that doesnt't have g/km
# mileage_in_kg -> integer
#offer_description remove

# %%
def finxing_fuel_type(ft):
    if ft in ['Petrol', 'Diesel', 'Hybrid', 'Electric', 'LPG', 'Diesel Hybrid', 'Hydrogen', 'CNG', 'Ethanol', 'Other']:
        return ft
    else: 
        return None
def fixing_fuel_consumption_1_100km(fc):
    if 'l_100km' in fc:
        pos = fc.find(' l_100km') #this prepare the values to be turned into floats later
        return fc[:pos]
    else: 
        return None
    
def fixing_fuel_consumption_g_km(fc): 
    if 'g_km' in fc:
        pos = fc.find(' g_km') #this prepare the values to be turned into floats later
        return fc[:pos]
    else: 
        return None

def formating_dataframe(df):
    print(f'Initial length of the dataframe: {len(df)}')
    
    # No null values
    df.dropna(axis = 'columns', inplace = True)

    # REMOVE columns
    df.drop(['model', 'color', 'offer_description', 'registration_date'], axis = 1, inplace = True)

    #Transform fuel_type. 
    df['fuel_type'] = df['fuel_type'].apply(finxing_fuel_type)


    #Transform fuel_consumption
    df['fuel_consumption_l_100km'] = df['fuel_consumption_l_100km'].apply(fixing_fuel_consumption_1_100km)
    
    df['fuel_consumption_g_km'] = df['fuel_consumption_g_km'].apply(fixing_fuel_consumption_g_km)


    # Convert to integer
    df['year'] = df['year'].astype(int)
    df['price_in_euro'] = df['price_in_euro'].astype(int)
    df['power_kw'] = df['power_kw'].astype(int)
    df['power_ps'] = df['power_ps'].astype(int)
    df['mileage_in_km'] = df['mileage_in_km'].astype(int)
    
    # Convert to float
    df['fuel_consumption_l_100km'] = df['fuel_consumption_l_100km'].astype(int)
    df['fuel_consumption_g_km'] = df['fuel_consumption_g_km'].astype(int)

    
    # No null values
    df.dropna(axis = 'columns', inplace = True)
    
    print(f'Final length of the dataframe: {len(df)}')

    return df
df = formating_dataframe(df_train.copy())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 54
#      51     df.dropna(axis = 'columns', inplace = True)
#      53     return df
# ---> 54 df = formating_dataframe(df_train.copy())
#
# Cell In[15], line 26, in formating_dataframe(df)
#      23 df.dropna(axis = 'columns', inplace = True)
#      25 # REMOVE columns
# ---> 26 df.drop(['model', 'color', 'offer_description', 'registration_date'], axis = 1, inplace = True)
#      28 #Transform fuel_type.
#      29 df['fuel_type'] = df['fuel_type'].apply(finxing_fuel_type)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['color'] not found in axis"

# %%
df = formating_dataframe(df_train.copy())
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = formating_dataframe(df_train.copy())
#       2 df.head()
#
# Cell In[12], line 32, in formating_dataframe(df)
#      28 df['fuel_type'] = df['fuel_type'].apply(finxing_fuel_type)
#      31 #Transform fuel_consumption
# ---> 32 df['fuel_consumption_l_100km'] = df['fuel_consumption_l_100km'].apply(fixing_fuel_consumption_1_100km)
#      34 df['fuel_consumption_g_km'] = df['fuel_consumption_g_km'].apply(fixing_fuel_consumption_g_km)
#      37 # Convert to integer
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1156, in SeriesApply.apply_standard(self)
#    1154     else:
#    1155         values = obj.astype(object)._values
# -> 1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
#    1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\lib.pyx:2918, in pandas._libs.lib.map_infer()
#
# Cell In[12], line 9, in fixing_fuel_consumption_1_100km(fc)
#       8 def fixing_fuel_consumption_1_100km(fc):
# ----> 9     if 'l_100km' in fc:
#      10         pos = fc.find(' l_100km') #this prepare the values to be turned into floats later
#      11         return fc[:pos]
#
# TypeError: argument of type 'float' is not iterable
